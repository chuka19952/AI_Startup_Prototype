# %% [markdown]
# <a href="https://colab.research.google.com/github/chuka19952/AI_Startup_Prototype/blob/master/Vaccine_code_and_modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('extracted-tweets.txt', names=['content'])

# %%
df.head()
# Out:
#                                              content
# 0  '@dave_rohl @MartinGorrie I have been jabbed. ...
# 1  'COVID-19 Vaccine Checklist for Kids Age 5 and...
# 2  '@SenRickScott Vaccine mandates protect worker...
# 3  'Ontario will NOT mandate COVID-19 vaccine pol...
# 4  Many of my colleagues who have young kids saw ...

# %%
df.shape
# Out:
# (35164, 1)

# %%
# Cleaning the data with  PorterStemmer
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
corpus = []
for i in range(0, 35163):
    review = re.sub('[^a-zA-Z]', ' ', df['content'][i])
    review = review.lower()
    review = review.split()
    ps = PorterStemmer()  #Also try sowallstemmer
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Cleaning the data with  SnowballStemmer
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
corpus = []
for i in range(0, 1000):
    review = re.sub('[^a-zA-Z]', ' ', df['content'][i])
    review = review.lower()
    review = review.split()
    s_stemmer = SnowballStemmer(language='english')
    review = [s_stemmer.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Out:
# ['dave rohl martingorri jab covid n neven got jab experiment hiv vax year ago n nyou read consent form litig shield lot n nlive vaccin wors',
#  'covid vaccin checklist kid age https co oyocahp qa',
#  'senrickscott vaccin mandat protect worker famili nmore',
#  'ontario mandat covid vaccin polici hospit worker n n holdthelin n n taniahopkin jelenawild karthik es justmelissa arwenstar armyofshadow ealeorah rgcrypto metro west psyop dannybloom kellzbellzzah n nhttps co fgzpn qwwu via youtub',
#  'mani colleagu young kid saw earli christma present getvaccin ncdc recommend pfizer covid vaccin children age https co e ppid',
#  'nwlaguy busi deni covid fight vaccin',
#  'ericdjuli vaccin guarante protect covid',
#  'chrispbrink onthospitalassn actual vaccin mandat vaccin test mandat believ n meantim',
# ...

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:, 1].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
# Fitting Naive Bayes to the Training set
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
